# %%
import time
import urllib2
from urllib2 import urlopen
import datetime
import pandas as pd

# %%
url = 'http://crkyo.wordpress.com/page/'
thirty = range(1,31)

urls = list()

for x in thirty:
    urls.append(url+str(x))

# %%
def reader():
    for x in urls:
        try:
            print urllib2.urlopen(x).read()
        except urllib2.HTTPError, e:
            print e.code
            print e.msg
            print e.headers
            print e.fp.read()
            
reader()
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <!--
# 	generated in 0.219 seconds
# 	51445 bytes batcached for 300 seconds
# -->
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <title>crkyo | Smile! You’re at the best WordPress.com site ever</title>
# <link rel="profile" href="http://gmpg.org/xfn/11">
# <link rel="pingback" href="https://crkyo.wordpress.com/xmlrpc.php">
#
# <link rel="alternate" type="application/rss+xml" title="crkyo &raquo; Feed" href="https://crkyo.wordpress.com/feed/" />
# <link rel="alternate" type="application/rss+xml" title="crkyo &raquo; Comments Feed" href="https://crkyo.wordpress.com/comments/feed/" />
# <script type="text/javascript">
# /* <![CDATA[ */
# function addLoadEvent(func){var oldonload=window.onload;if(typeof window.onload!='function'){window.onload=func;}else{window.onload=function(){oldonload();func();}}}
# /* ]]> */
# </script>
# <link rel='stylesheet' id='all-css-0' href='https://s0.wp.com/_static/??-' type='text/css' media='all' />
# <link rel='stylesheet' id='minnow-opensans-css'  href='//fonts.googleapis.com/css?family=Open+Sans%3A300%2C400%2C700%2C700italic%2C400italic%2C300italic%7COpen+Sans+Condensed%3A700%2C700italic&#038;subset=latin%2Clatin-ext' type='text/css' media='all' />
# <link rel='stylesheet' id='all-css-2' href='https://s2.wp.com/_static/??-eJx9j8EKwjAQRH/IuNoWehK/JQlrumWzG5qE4N9bqUhF6GWYgfcOAy0Zr1JQCpQJI2ZI1UEkEW1A4iGXJ6NpyWs8+5xPsDNiNYlrIMmAUWfacsMIRAutZP6WIz+gGlZvC6n8DPNgS8uRuqBjDWsNsFK7+Sd9Hk4DBFZn+Q3c4+06dJexH4eun1++gWSm' type='text/css' media='all' />
# <link rel='stylesheet' id='print-css-2' href='https://s0.wp.com/wp-content/mu-plugins/global-print/global-print.css?m=1387483371g' type='text/css' media='print' />
# <script type='text/javascript'>
# /* <![CDATA[ */
# var LoggedOutFollow = {"invalid_email":"Your subscription did not succeed, please try again with a valid email address."};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s0.wp.com/_static/??-eJyFkNsOwiAMQH9IxrZo4ovxW3bpSBEoUhjRrxeTGTXO7KlNe9LTVmYvBnIRXJSapaUeDYjEEDpVagLdRJXmnSwcusGkEfgJ6muCcFvCJiAsqtBFqCy6F/xh9cTRAnNRrnS/VehmhLyJaYi+Gy4iAOP9Z2pvSAlvkkLHsuQKRkpRTGQMZZlxVBDXjmL/3v//NxbqbE/Nvq4Px6atW/0AiPqGzQ=='></script>
# <link rel='stylesheet' id='all-css-0' href='https://s2.wp.com/wp-content/mu-plugins/highlander-comments/style.css?m=1377793621g' type='text/css' media='all' />
# <!--[if lt IE 8]>
# <link rel='stylesheet' id='highlander-comments-ie7-css'  href='https://s2.wp.com/wp-content/mu-plugins/highlander-comments/style-ie7.css?m=1351637563g&#038;ver=20110606' type='text/css' media='all' />
# <![endif]-->
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://crkyo.wordpress.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://s1.wp.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress.com" />
# <link rel='shortlink' href='http://wp.me/4B8Q1' />
#
# <!-- Jetpack Open Graph Tags -->
# <meta property="og:type" content="website" />
# <meta property="og:title" content="crkyo" />
# <meta property="og:description" content="Smile! You’re at the best WordPress.com site ever" />
# <meta property="og:url" content="https://crkyo.wordpress.com/" />
# <meta property="og:site_name" content="crkyo" />
# <meta property="og:image" content="https://s0.wp.com/i/blank.jpg" />
# <meta name="twitter:site" content="@wordpressdotcom" />
# <meta property="fb:app_id" content="249643311490" />
# <link rel="shortcut icon" type="image/x-icon" href="https://s2.wp.com/i/favicon.ico" sizes="16x16 24x24 32x32 48x48" />
# <link rel="icon" type="image/x-icon" href="https://s2.wp.com/i/favicon.ico" sizes="16x16 24x24 32x32 48x48" />
# <link rel="apple-touch-icon-precomposed" href="https://s0.wp.com/i/webclip.png" />
# <link rel='openid.server' href='https://crkyo.wordpress.com/?openidserver=1' />
# <link rel='openid.delegate' href='https://crkyo.wordpress.com/' />
# <link rel="search" type="application/opensearchdescription+xml" href="https://crkyo.wordpress.com/osd.xml" title="crkyo" />
# <link rel="search" type="application/opensearchdescription+xml" href="http://wordpress.com/opensearch.xml" title="WordPress.com" />
# 		<style type="text/css">
# 			.recentcomments a {
# 				display: inline !important;
# 				padding: 0 !important;
# 				margin: 0 !important;
# 			}
#
# 			table.recentcommentsavatartop img.avatar, table.recentcommentsavatarend img.avatar {
# 				border: 0px;
# 				margin: 0;
# 			}
#
# 			table.recentcommentsavatartop a, table.recentcommentsavatarend a {
# 				border: 0px !important;
# 				background-color: transparent !important;
# 			}
#
# 			td.recentcommentsavatarend, td.recentcommentsavatartop {
# 				padding: 0px 0px 1px 0px;
# 				margin: 0px;
# 			}
#
# 			td.recentcommentstextend {
# 				border: none !important;
# 				padding: 0px 0px 2px 10px;
# 			}
#
# 			.rtl td.recentcommentstextend {
# 				padding: 0px 10px 2px 0px;
# 			}
#
# 			td.recentcommentstexttop {
# 				border: none;
# 				padding: 0px 0px 0px 10px;
# 			}
#
# 			.rtl td.recentcommentstexttop {
# 				padding: 0px 10px 0px 0px;
# 			}
# 		</style>
# 		<meta name="application-name" content="crkyo" /><meta name="msapplication-window" content="width=device-width;height=device-height" /><meta name="msapplication-tooltip" content="Smile! You’re at the best WordPress.com site ever" /><meta name="msapplication-task" content="name=Subscribe;action-uri=https://crkyo.wordpress.com/feed/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="msapplication-task" content="name=Sign up for a free blog;action-uri=http://wordpress.com/signup/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="msapplication-task" content="name=WordPress.com Support;action-uri=http://support.wordpress.com/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="msapplication-task" content="name=WordPress.com Forums;action-uri=http://forums.wordpress.com/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="title" content="crkyo on WordPress.com" />
# <meta name="description" content="Smile! You’re at the best WordPress.com site ever" />
# <style type="text/css" id="syntaxhighlighteranchor"></style>
# </head>
#
# <body class="home blog mp6 highlander-enabled highlander-light infinite-scroll neverending">
# <div id="page" class="hfeed site">
# 	<a class="skip-link screen-reader-text" href="#content">Skip to content</a>
#
# 	<header id="masthead" class="site-header" role="banner">
#
# 		<div class="site-branding">
# 													<h1 class="site-title"><a href="https://crkyo.wordpress.com/" rel="home">crkyo</a></h1>
# 			<h2 class="site-description">Smile! You’re at the best WordPress.com site ever</h2>
# 		</div>
#
#
# 				<div class="slide-menu">
#
#
# 		</div>
# 	</header><!-- #masthead -->
#
# 	<div id="content" class="site-content">
#
# 	<div id="primary" class="content-area">
# 		<main id="main" class="site-main" role="main">
#
#
#
#
# <article id="post-215" class="post-215 post type-post status-publish format-standard hentry category-uncategorized">
# 	<header class="entry-header">
# 					<h1 class="entry-title"><a href="https://crkyo.wordpress.com/2015/01/07/test/" rel="bookmark">Test</a></h1>
# 				<div class="entry-meta">
# 			<span class="posted-on"><a href="https://crkyo.wordpress.com/2015/01/07/test/" rel="bookmark"><time class="entry-date published updated" datetime="2015-01-07T12:51:49+00:00">January 7, 2015</time></a></span><span class="byline"> <span class="author vcard"><a class="url fn n" href="https://crkyo.wordpress.com/author/crkyo/">crkyo</a></span></span><span class="comments-link"><a href="https://crkyo.wordpress.com/2015/01/07/test/#respond" title="Comment on Test">Leave a comment</a></span>		</div><!-- .entry-meta -->
#
# 			</header><!-- .entry-header -->
#
# 	<div class="entry-content">
# 		<p>test</p>
#
# 			</div><!-- .entry-content -->
#
# 	<div class="entry-format">
# 		<a href="https://crkyo.wordpress.com/2015/01/07/test/"><span class="screen-reader-text">Test</span></a>	</div>
# </article><!-- #post-## -->
#
#
#
# <article id="post-6" class="post-6 post type-post status-publish format-standard hentry category-uncategorized tag-awareness tag-evil tag-fear tag-good tag-philosophy tag-reason">
# 	<header class="entry-header">
# 					<h1 class="entry-title"><a href="https://crkyo.wordpress.com/2013/01/16/the-falls-of-truth/" rel="bookmark">The Falls of&nbsp;Truth</a></h1>
# 				<div class="entry-meta">
# 			<span class="posted-on"><a href="https://crkyo.wordpress.com/2013/01/16/the-falls-of-truth/" rel="bookmark"><time class="entry-date published updated" datetime="2013-01-16T03:33:10+00:00">January 16, 2013</time></a></span><span class="byline"> <span class="author vcard"><a class="url fn n" href="https://crkyo.wordpress.com/author/crkyo/">crkyo</a></span></span><span class="tags-links"><a href="https://crkyo.wordpress.com/tag/awareness/" rel="tag">awareness</a>, <a href="https://crkyo.wordpress.com/tag/evil/" rel="tag">evil</a>, <a href="https://crkyo.wordpress.com/tag/fear/" rel="tag">fear</a>, <a href="https://crkyo.wordpress.com/tag/good/" rel="tag">good</a>, <a href="https://crkyo.wordpress.com/tag/philosophy/" rel="tag">philosophy</a>, <a href="https://crkyo.wordpress.com/tag/reason/" rel="tag">reason</a></span><span class="comments-link"><a href="https://crkyo.wordpress.com/2013/01/16/the-falls-of-truth/#respond" title="Comment on The Falls of&nbsp;Truth">Leave a comment</a></span>		</div><!-- .entry-meta -->
#
# 			</header><!-- .entry-header -->
#
# 	<div class="entry-content">
# 		<p>Random thought that occurred to me as I was lying in bed:</p>
# <p>If I&#8217;ve learned anything from watching anime, it&#8217;s that you need to understand your own dark side, accept it and embrace it. &nbsp;If you don&#8217;t, you lose the capacity for reason, and also turn into a rampaging living form of energy in the shape of a giant fox. &nbsp;</p>
# <p>All fanboyism aside, this very sensible concept led me to wonder &#8211; what is it that permits us to reason and accept the parts of humanity that we would prefer to turn our backs on or even refuse to acknowledge? &nbsp;Must we first be capable of reason in order to accept the evils of humanity? &nbsp;Do those who never really face their demons simply fail to reason with themselves? &nbsp;Are they just cursed with a smaller capacity to reason, or a larger sense of evil? &nbsp;Perhaps both are possible. &nbsp;Maybe the key is simply intent. &nbsp;Those who choose to reason make themselves reason and those who choose not to just don&#8217;t. &nbsp;</p>
# <p>If that&#8217;s the case, what is it then that influences us to reason? &nbsp;What makes us choose to acknowledge humanity&#8217;s capacity for evil? &nbsp;What could possibly influence someone to look at evil and say &#8220;I understand&#8221;? &nbsp;Of course, there are many mechanisms constructed to defend us from such a dark place. &nbsp;The first that comes to mind is the idea that an omnipotent force will determine what happens to the good and the evil, freeing us from the burden of coming to terms with ourselves. &nbsp;We construct ways to absolve us from dealing with what makes us human. &nbsp;If we know what it is that allows us to understand evil however, we might have the opportunity to better deal with it.</p>
# <p>Perhaps those who are more inclined to understand evil have had more experience with it. &nbsp;Those who find reason in the dark recesses of humanity may have spent time walking around in it, lost and finding a way out, or even just looking around. &nbsp;The first thing I am reminded of are dark humor comedians. &nbsp;Comedy and tragedy are classically polar opposites, however I think comedy is tragic in a way. &nbsp;Sometimes it draws the line where many people are afraid to go, it identifies a darkness that some people refuse to acknowledge &#8211; and that in itself is a tragedy.</p>
# <p>It is quite the dilemma&#8230; &nbsp;In order to face darkness one must not be afraid of the unknown. &nbsp;In order to not be afraid of the unknown one must conquer fear. &nbsp;In order to conquer fear one must embrace the unknown, and in order to embrace the unknown &#8211; that&#8217;s right: one must face darkness.</p>
#
# 			</div><!-- .entry-content -->
#
# 	<div class="entry-format">
# 		<a href="https://crkyo.wordpress.com/2013/01/16/the-falls-of-truth/"><span class="screen-reader-text">The Falls of&nbsp;Truth</span></a>	</div>
# </article><!-- #post-## -->
#
#
#
# <article id="post-7" class="post-7 post type-post status-publish format-standard hentry category-uncategorized tag-astral-projection tag-awareness tag-meditation">
# 	<header class="entry-header">
# 					<h1 class="entry-title"><a href="https://crkyo.wordpress.com/2013/01/13/self-reminder/" rel="bookmark">&#8220;Self&#8221; Reminder</a></h1>
# 				<div class="entry-meta">
# 			<span class="posted-on"><a href="https://crkyo.wordpress.com/2013/01/13/self-reminder/" rel="bookmark"><time class="entry-date published updated" datetime="2013-01-13T06:50:57+00:00">January 13, 2013</time></a></span><span class="byline"> <span class="author vcard"><a class="url fn n" href="https://crkyo.wordpress.com/author/crkyo/">crkyo</a></span></span><span class="tags-links"><a href="https://crkyo.wordpress.com/tag/astral-projection/" rel="tag">astral projection</a>, <a href="https://crkyo.wordpress.com/tag/awareness/" rel="tag">awareness</a>, <a href="https://crkyo.wordpress.com/tag/meditation/" rel="tag">meditation</a></span><span class="comments-link"><a href="https://crkyo.wordpress.com/2013/01/13/self-reminder/#respond" title="Comment on &#8220;Self&#8221; Reminder">Leave a comment</a></span>		</div><!-- .entry-meta -->
#
# 			</header><!-- .entry-header -->
#
# 	<div class="entry-content">
# 		<p style="text-align:left;">Your computer is off. &nbsp;Your phone is off. &nbsp;There is little to zero electromagnetic interference in your immediate surroundings. &nbsp;</p>
# <p>You are sitting, and your eyes are closed. &nbsp;The first thing you notice is the unusual silence. &nbsp;You focus on your heart. &nbsp;You envision the blood pumping through your heart travel throughout your body. &nbsp;You envision the energy within your body, pulsating and flowing. &nbsp;You try to control the flowing energy&#8217;s direction. &nbsp;You like to think it works but you&#8217;re pretty sure that for now it&#8217;ll just be something you saw on TV. You settle with familiarizing yourself with as many muscles in your body as you can. &nbsp;You start at the top and subtly move your face muscles, then tense and release your neck muscles, and then the muscles in your upper body, your arms, your fingers, your shoulders. &nbsp;Now your lower body, your stomach, your lower back, you flex your butt and smirk. &nbsp;Then you tense and relax your thighs, then your calves and wiggle your toes.</p>
# <p>You realize the entity that is you, your body. &nbsp;Your eyes are still closed, and you imagine yourself floating out of your body, above your head. &nbsp;Your eyes are still closed. &nbsp;You imagine the room you are in, and where everything in the room is. &nbsp;You pretend to float your out-of-body-self to the bathroom because it&#8217;s kinda funny. &nbsp;You imagine where the bathroom is. &nbsp;You imagine where other rooms are. &nbsp;You float above the building you are in, and you envision the streets around you. &nbsp;You imagine the network of roads, and the complex highway system connecting the country. &nbsp;You float even higher, and look down to see cities with life humming quietly like a living generator. &nbsp;You envision people living their every-day lives, as well as acknowledging the infinite possibility of unconventional lifestyles. &nbsp;You float even higher, you see coastlines and country borders. &nbsp;You realize there are whole continents of countries, whole oceans of water, all connected by your vision.</p>
# <p>You float higher.</p>
# <p>Your eyes are still closed.</p>
# <p>You watch the planet become smaller and smaller, as the backdrop of space becomes larger and larger. &nbsp;You imagine the Earth in its orbit, and its satellite moon. &nbsp;You imagine Earth&#8217;s neighboring planets, and the presence of the solar system. &nbsp;You float even further away. &nbsp;</p>
# <p>You imagine the Milky Way Galaxy, filled with billions of stars, and thriving with energy. &nbsp;You imagine an unidentifiable number of planets within the galaxy. &nbsp;You float higher.</p>
# <p>You envision galaxies lining up just as solar systems do, just as planets do, just as countries do, just as buildings do. &nbsp;You find yourself pulling back down, so you float even higher until everything you&#8217;ve just flown by becomes a speck in your field of vision. &nbsp;Where are you?</p>
# <p>It is silent. &nbsp;You&#8217;ve forgotten your heartbeat &#8211; it is still there with you. &nbsp;What do you notice? &nbsp;What do you realize? &nbsp;</p>
# <p>You&nbsp;reacquaint&nbsp;yourself with the oneness of your consciousness. &nbsp;Your heartbeat, the flowing energy within your body, each muscle in each limb, and each appendage. &nbsp;Your eyes are still closed.</p>
# <p>You look back at what you&#8217;ve just flown by and you rocket back down, down past universes filled with galaxies, filled with stars, past millions of planets. &nbsp;Down past Pluto, Uranus, Neptune, Saturn, Jupiter, past Mars, through the Earth&#8217;s atmosphere. &nbsp;You aim for your building and you shoot down, the coastline escaping your field of vision until all you see is land. &nbsp;You imagine yourself back in your room.</p>
# <p>Now your eyes are open.</p>
#
# 			</div><!-- .entry-content -->
#
# 	<div class="entry-format">
# 		<a href="https://crkyo.wordpress.com/2013/01/13/self-reminder/"><span class="screen-reader-text">&#8220;Self&#8221; Reminder</span></a>	</div>
# </article><!-- #post-## -->
#
#
#
# <article id="post-8" class="post-8 post type-post status-publish format-standard hentry category-uncategorized">
# 	<header class="entry-header">
# 					<h1 class="entry-title"><a href="https://crkyo.wordpress.com/2012/11/22/rambling/" rel="bookmark">Rambling</a></h1>
# 				<div class="entry-meta">
# 			<span class="posted-on"><a href="https://crkyo.wordpress.com/2012/11/22/rambling/" rel="bookmark"><time class="entry-date published updated" datetime="2012-11-22T13:53:20+00:00">November 22, 2012</time></a></span><span class="byline"> <span class="author vcard"><a class="url fn n" href="https://crkyo.wordpress.com/author/crkyo/">crkyo</a></span></span><span class="comments-link"><a href="https://crkyo.wordpress.com/2012/11/22/rambling/#respond" title="Comment on Rambling">Leave a comment</a></span>		</div><!-- .entry-meta -->
#
# 			</header><!-- .entry-header -->
#
# 	<div class="entry-content">
# 		<p style="text-align:center;"><span style="font-family:georgia, palatino;"><span style="font-size:x-large;">&#8220;Give me six hours to chop down a tree and I will spend the first four sharpening the axe.&#8221;</span>&nbsp;</span></p>
# <p style="text-align:center;"><span style="font-family:georgia, palatino;">-Abraham Lincoln<br /></span></p>
# <p><span style="font-family:georgia, palatino;">&nbsp;</span></p>
# <p><span style="font-family:georgia, palatino;">We live in marvelous times. &nbsp;Amid the fever of global economic strife, the dawn of a new era in physics, a waning period for consumer technology, and only weeks before &#8220;the end of the world&#8221;, I think a general mentality of conformity encompasses our society. &nbsp;This is only natural, for people and animals alike to tighten together within a community when a sense of danger persists, a sense of uncertainty and lack of direction. &nbsp;There are many valid conservative arguments against non-conformity; the notion that when you put yourself at exceptional risk, no one is obligated to save you. &nbsp;Risk is a very complicated concept though, and as conservative as I am compelled to be in times like these, I think there is a very alluring and unusually noble concept behind it. &nbsp;What makes these times so extraordinary is that they are filled with opportunity. &nbsp;<br /></span></p>
# <p><span style="font-family:georgia, palatino;">I&#8217;ve been looking for motivation lately and have been having a hard time finding it. &nbsp;I&#8217;m my own worst enemy when I idle because I&#8217;m left to my own devices and that&#8217;s when I think the most. &nbsp;I&#8217;ve never felt so conformed to these times of uncertainty; when seeking for answers from my past or seeking for what might be in the future, I find very little. &nbsp;When my thoughts race I start fooling myself into forgetting what makes me who I am. &nbsp;I start trying to redefine myself by taking cues from my past and by attempting to project into the future. &nbsp;I begin remembering all my failures and all my incomplete dreams. &nbsp;It&#8217;s right at that moment, that critical moment of anti-clarity that somehow yields a paramount moment of clarity. &nbsp;</span></p>
# <p><span style="font-family:georgia, palatino;">All the things I used to want turned out to be things not suited for me &#8211; or perhaps I have changed to make that so. &nbsp;Likewise, all the dreams that remain but still have been just beyond my reach will remain there &#8211; until I change to make them so. &nbsp;My failure is my motivation.</span></p>
# <p><span style="font-family:georgia, palatino;">When the time comes to huddle together in the cold, when individual warmth won&#8217;t suffice &#8211; it is at that moment new opportunities arise. &nbsp;The opportunities to discover new answers fueled by questions unanswered, to learn new perspectives once hidden by myopic content. &nbsp;In times of distress, the opportunity of &#8220;risk&#8221; arises and you are given the option of behaving ordinarily, or extra-ordinarily. &nbsp;This is exactly why we live in marvelous times. &nbsp;There is distress all around us and everyone is huddled to keep warm in the cold of distress. &nbsp;Of course, we may all survive but only few will triumph. &nbsp;These times are the making of awe-inspiring stories that will last &#8211; hopefully longer than a twitter trend.</span></p>
# <p>&nbsp;</p>
#
# 			</div><!-- .entry-content -->
#
# 	<div class="entry-format">
# 		<a href="https://crkyo.wordpress.com/2012/11/22/rambling/"><span class="screen-reader-text">Rambling</span></a>	</div>
# </article><!-- #post-## -->
#
#
#
# <article id="post-9" class="post-9 post type-post status-publish format-standard hentry category-uncategorized">
# 	<header class="entry-header">
# 					<h1 class="entry-title"><a href="https://crkyo.wordpress.com/2012/11/19/on-socialism/" rel="bookmark">On Socialism</a></h1>
# 				<div class="entry-meta">
# 			<span class="posted-on"><a href="https://crkyo.wordpress.com/2012/11/19/on-socialism/" rel="bookmark"><time class="entry-date published updated" datetime="2012-11-19T16:11:18+00:00">November 19, 2012</time></a></span><span class="byline"> <span class="author vcard"><a class="url fn n" href="https://crkyo.wordpress.com/author/crkyo/">crkyo</a></span></span><span class="comments-link"><a href="https://crkyo.wordpress.com/2012/11/19/on-socialism/#respond" title="Comment on On Socialism">Leave a comment</a></span>		</div><!-- .entry-meta -->
#
# 			</header><!-- .entry-header -->
#
# 	<div class="entry-content">
# 		<p>I was listening to an underground rapper by the name of Prosperous Pete on youtube, who was discussing the issues of socialism and capitalism in today&rsquo;s America. &nbsp;Another viewer commented:</p>
# <blockquote><p>capitalism is slavery?! are you fucking kidding me? In America&rsquo;s most free and prosperous state we were the most Capitalist we&rsquo;ve ever been. The closer we get to socialism, the more power we give to our government, and te more money we give to our government, and they&rsquo;ve already proven that they do not know how to spend/save that money. You are clearly misguided or lost.</p>
# </blockquote>
# <p>As an amateur philosopher, I feel like this is the view most republicans and otherwise ignorant Americans have on socialism. &nbsp;Contrary to the belief of these people, socialism is not necessarily control by the government, but more exactly a political philosophy or system that endorses the ownership and control of production by the cooperation of the people. &nbsp;I would think that if anything, this is taking control away from the privatized industries, passing through the hands of the government, and into the hands of the people. &nbsp;</p>
# <p>Now I can see where most people might be afraid of socialism, the rich afraid of losing power, and the poor afraid of submitting themselves to the government instead of private companies. &nbsp;It seems depressing though to think that America as a people are incapable of watching the transfer of power from conglomerates to the government without actively revolting. &nbsp;Socialism, especially in the state of our economy, is best for the people. &nbsp;The minimum wage worker struggling to pay their bills will no longer have to sweat blood and tears while the CEO running the company they work for flies out to exotic countries to play golf with other CEOs. &nbsp;Instead, CEOs give up the jets they own so that poorer citizens can afford the luxuries that most people call necessities such as a mode of transportation, or an education. &nbsp;What is scary about socialism IS the overtaking of power by the government. &nbsp;This is because of the conditioning we have been submitted to through the submersion of common knowledge in the propaganda filtered through the media. &nbsp;We see other socialist countries that have succumbed to their leaders and see that the people are oppressed. &nbsp;Therefore, we associate socialism with oppression. &nbsp;However, I strongly believe that should the government take power from privately owned companies, and furthermore from the people, We as a country would not stand idly by to watch and cry. &nbsp;Americans are much stronger than that, there will come a time when the economy that is falling down onto us will cause this house to collapse, and the only people that will be up to the task of rebuilding it are US.</p>
# <p>&nbsp;&ldquo;We must ask ourselves what we want our story to be. What will our story be after we are all gone from this earth? In 100 years? In 1000 years? We alone determine the future, we alone have that power. Ask yourself, how do you want your story to go?&rdquo;</p>
#
# 			</div><!-- .entry-content -->
#
# 	<div class="entry-format">
# 		<a href="https://crkyo.wordpress.com/2012/11/19/on-socialism/"><span class="screen-reader-text">On Socialism</span></a>	</div>
# </article><!-- #post-## -->
#
#
#
# <article id="post-10" class="post-10 post type-post status-publish format-standard hentry category-uncategorized">
# 	<header class="entry-header">
# 					<h1 class="entry-title"><a href="https://crkyo.wordpress.com/2012/10/13/the-old-prince-outro-feat-kamau/" rel="bookmark">The Old Prince &#8211; Outro feat.&nbsp;Kamau</a></h1>
# 				<div class="entry-meta">
# 			<span class="posted-on"><a href="https://crkyo.wordpress.com/2012/10/13/the-old-prince-outro-feat-kamau/" rel="bookmark"><time class="entry-date published updated" datetime="2012-10-13T21:30:33+00:00">October 13, 2012</time></a></span><span class="byline"> <span class="author vcard"><a class="url fn n" href="https://crkyo.wordpress.com/author/crkyo/">crkyo</a></span></span><span class="comments-link"><a href="https://crkyo.wordpress.com/2012/10/13/the-old-prince-outro-feat-kamau/#respond" title="Comment on The Old Prince &#8211; Outro feat.&nbsp;Kamau">Leave a comment</a></span>		</div><!-- .entry-meta -->
#
# 			</header><!-- .entry-header -->
#
# 	<div class="entry-content">
# 		<p><span>&#8220;We spend our lives searching, like scavengers finding a way,&nbsp;</span><br /><span>Understanding that light is a sign of the day.</span><br /><span>So we squint in the darkness in search of a glow,</span><br /><span>And falter in trying,&nbsp;</span><br /><span>In trials we grow.</span><br /><span>Our hearts they seem broken,</span><br /><span>Our legs they are weak,</span><br /><span>Our tongues are exhausted from trying to speak.</span><br /><span>&lsquo;Cause sometimes they listen,&nbsp;</span><br /><span>But often they don&rsquo;t.</span><br /><span>We easily help,</span><br /><span>But more often we won&rsquo;t.</span><br /><span>Because we&#8217;ve constructed the things that we want,</span><br /><span>Ghosts are desires,</span><br /><span>Desire to haunt.</span><br /><span>But our need as below so above</span><br /><span>What we all want</span><br /><span>Should look a little more&nbsp;</span><br /><span>Like love.&#8221; &nbsp;-<strong>Shad</strong></span></p>
#
# 			</div><!-- .entry-content -->
#
# 	<div class="entry-format">
# 		<a href="https://crkyo.wordpress.com/2012/10/13/the-old-prince-outro-feat-kamau/"><span class="screen-reader-text">The Old Prince &#8211; Outro feat.&nbsp;Kamau</span></a>	</div>
# </article><!-- #post-## -->
#
#
#
# <article id="post-11" class="post-11 post type-post status-publish format-standard hentry category-uncategorized">
# 	<header class="entry-header">
# 					<h1 class="entry-title"><a href="https://crkyo.wordpress.com/2012/08/03/how-real-is-real/" rel="bookmark">How real is&nbsp;real?</a></h1>
# 				<div class="entry-meta">
# 			<span class="posted-on"><a href="https://crkyo.wordpress.com/2012/08/03/how-real-is-real/" rel="bookmark"><time class="entry-date published updated" datetime="2012-08-03T05:51:39+00:00">August 3, 2012</time></a></span><span class="byline"> <span class="author vcard"><a class="url fn n" href="https://crkyo.wordpress.com/author/crkyo/">crkyo</a></span></span><span class="comments-link"><a href="https://crkyo.wordpress.com/2012/08/03/how-real-is-real/#respond" title="Comment on How real is&nbsp;real?">Leave a comment</a></span>		</div><!-- .entry-meta -->
#
# 			</header><!-- .entry-header -->
#
# 	<div class="entry-content">
# 		<p>If we are all made of the same galactic cloth, then at some quantum level we must all resonate with one another. &nbsp;Of course, directly, one could resonate one&#8217;s hand with another&#8217;s face, but the resonance I&#8217;m referring to is one of galactic proportions. &nbsp;</p>
# <p>I had a dream on August 1, 2012. &nbsp;I date this particular dream because this particular dream is important to me and here is the only place I can successfully remind myself when I want to remember it. &nbsp;The dream I had involved me exploring a small town. &nbsp;It was late afternoon and just beginning to get dark. &nbsp;I cut through lawns and came to a large fountain that I could walk through. &nbsp;The water was only ankle deep, but I&#8217;d gotten my pants soaked. &nbsp;I came to a tall building with only a stairwell inside. &nbsp;I looked up the stairwell and saw an old friend looking down at me, calling to me while walking up the stairway. &nbsp;I couldn&#8217;t make out what she said but suddenly she was gone. &nbsp;I went back outside to walk around the town, passed by the fountain again, and finally went back to the stairwell. &nbsp;I walked out and saw another old friend standing on a balcony. &nbsp;I talked to him, and as we talked, people flooded the balcony. &nbsp;I backed away to see my friend from the stairwell standing in a circle of people, and as I walked away, I watched her focus on the people around her. &nbsp;She turned to me and gave me a look as if saying good bye. &nbsp;</p>
# <p>I woke up heartbroken. &nbsp;</p>
# <p>I realized that I&#8217;d cut ties with many people in my life, rarely intentionally, mostly due to carelessness and absent-mindedness. &nbsp;It &#8216;s that absent-mindedness though that I fought so hard to grow out of. &nbsp;It was that absent-mindedness that gave me that dream, grasping at me from my sub-consciousness. &nbsp;</p>
# <p>I wondered how my old friend was doing. &nbsp;Last I&#8217;d heard she was as happy as she&#8217;d always wanted to be, but that was still a long, long time ago. &nbsp;I realized that I&#8217;d never actually told her what she meant to me. &nbsp;I never got to blame her for introducing me to astrology which now influences a significant part of my life. &nbsp;I never got to thank her for being a good friend, and to apologize for being a jackass when I was, which was probably a majority of the time she knew me. &nbsp;</p>
# <p>Nevertheless, I found myself searching for a ghost no one knew how to find. &nbsp;I began wondering if the dream I had wasn&#8217;t just my sub-conscious, but an actual visit&#8230; &nbsp;I searched everywhere for clues and hints &#8211; I became fuckin&#8217; Sherlock Holmes (I&#8217;ve also been watching too much Burn Notice lately), but no solid leads means resorting to Xanga to let off a little bit. &nbsp;I can&#8217;t lie, my curiosity has kept me up hoping my dream was just a dream, and wondering if energy could be directed in such a fashion to communicate. &nbsp;Sure, that&#8217;s just me dreaming, but how real is real?</p>
#
# 			</div><!-- .entry-content -->
#
# 	<div class="entry-format">
# 		<a href="https://crkyo.wordpress.com/2012/08/03/how-real-is-real/"><span class="screen-reader-text">How real is&nbsp;real?</span></a>	</div>
# </article><!-- #post-## -->
#
#
# 				<nav class="navigation paging-navigation" role="navigation">
# 		<h1 class="screen-reader-text">Posts navigation</h1>
# 		<div class="nav-links">
#
# 						<div class="nav-previous"><a href="https://crkyo.wordpress.com/page/2/" ><span class="meta-nav">&larr;</span> Older posts</a></div>
#
#
# 		</div><!-- .nav-links -->
# 	</nav><!-- .navigation -->
#
#
# 		</main><!-- #main -->
# 	</div><!-- #primary -->
#
#
# 	</div><!-- #content -->
#
# 	<footer id="colophon" class="site-footer" role="contentinfo">
# 		<div class="site-info">
# 			<a href="https://wordpress.com/?ref=footer_blog">Blog at WordPress.com</a>.
# 			<span class="sep"> | </span>
# 			<a href="https://wordpress.com/themes/minnow/" title="Learn more about this theme">The Minnow Theme</a>.		</div><!-- .site-info -->
# 	</footer><!-- #colophon -->
# </div><!-- #page -->
#
# 		<script type="text/javascript">
# 		//<![CDATA[
# 		var infiniteScroll = {"settings":{"id":"main","ajaxurl":"https:\/\/crkyo.wordpress.com\/?infinity=scrolling","type":"scroll","wrapper":true,"wrapper_class":"infinite-wrap","footer":"primary","click_handle":"1","text":"Older posts","totop":"Scroll back to top","currentday":"03.08.12","order":"DESC","scripts":[],"styles":[],"google_analytics":false,"offset":0,"history":{"host":"crkyo.wordpress.com","path":"\/page\/%d\/","use_trailing_slashes":true,"parameters":""},"query_args":{"error":"","m":"","p":0,"post_parent":"","subpost":"","subpost_id":"","attachment":"","attachment_id":0,"name":"","static":"","pagename":"","page_id":0,"second":"","minute":"","hour":"","day":0,"monthnum":0,"year":0,"w":0,"category_name":"","tag":"","cat":"","tag_id":"","author":"","author_name":"","feed":"","tb":"","paged":0,"comments_popup":"","meta_key":"","meta_value":"","preview":"","s":"","sentence":"","fields":"","menu_order":"","category__in":[],"category__not_in":[],"category__and":[],"post__in":[],"post__not_in":[],"tag__in":[],"tag__not_in":[],"tag__and":[],"tag_slug__in":[],"tag_slug__and":[],"post_parent__in":[],"post_parent__not_in":[],"author__in":[],"author__not_in":[],"posts_per_page":7,"ignore_sticky_posts":false,"suppress_filters":false,"cache_results":false,"update_post_term_cache":true,"update_post_meta_cache":true,"post_type":"","nopaging":false,"comments_per_page":"50","no_found_rows":false,"order":"DESC"},"last_post_date":"2012-08-03 05:51:39","stats":"blog=67957457&v=wpcom&tz=0&user_id=0&subd=crkyo&x_pagetype=infinite"}};
# 		//]]>
# 		</script>
# 		<!-- wpcom_wp_footer -->
# <script type='text/javascript' src='//0.gravatar.com/js/gprofiles.js?ver=201504x'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s2.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1380573781g'></script>
#
# 	<script>
# 		//initialize and attach hovercards to all gravatars
# 		jQuery( document ).ready( function( $ ) {
#
# 			if (typeof Gravatar === "undefined"){
# 				return;
# 			}
#
# 			if ( typeof Gravatar.init !== "function" ) {
# 				return;
# 			}
#
# 			Gravatar.profile_cb = function( hash, id ) {
# 				WPGroHo.syncProfileData( hash, id );
# 			};
# 			Gravatar.my_hash = WPGroHo.my_hash;
# 			Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 		});
# 	</script>
#
# 		<div style="display:none">
# 	</div>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var HighlanderComments = {"loggingInText":"Logging In\u2026","submittingText":"Posting Comment\u2026","postCommentText":"Post Comment","connectingToText":"Connecting to %s","commentingAsText":"%1$s: You are commenting using your %2$s account.","logoutText":"Log Out","loginText":"Log In","connectURL":"https:\/\/crkyo.wordpress.com\/public.api\/connect\/?action=request","logoutURL":"https:\/\/crkyo.wordpress.com\/wp-login.php?action=logout&_wpnonce=45aa98b04a","homeURL":"https:\/\/crkyo.wordpress.com\/","postID":"215","gravDefault":"identicon","enterACommentError":"Please enter a comment","enterEmailError":"Please enter your email address here","invalidEmailError":"Invalid email address","enterAuthorError":"Please enter your name here","gravatarFromEmail":"This picture will show whenever you leave a comment. Click to customize it.","logInToExternalAccount":"Log in to use details from one of these accounts.","change":"Change","changeAccount":"Change Account","comment_registration":"0","userIsLoggedIn":"","isJetpack":"0"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s0.wp.com/_static/??/wp-content/js/jquery/jquery.autoresize.js,/wp-content/mu-plugins/highlander-comments/script.js?m=1414003384j'></script>
# 		<div id="infinite-footer">
# 			<div class="container">
# 				<div class="blog-info">
# 					<a id="infinity-blog-title" href="https://crkyo.wordpress.com/" rel="home">
# 						crkyo					</a>
# 				</div>
# 				<div class="blog-credits">
# 					<a href="https://wordpress.com/?ref=footer_website">Create a free website or blog at WordPress.com</a>. <a href="https://wordpress.com/themes/minnow/" title="Learn more about this theme">The Minnow Theme</a>.				</div>
# 			</div>
# 		</div><!-- #infinite-footer -->
#
# 	<div id="bit" class="loggedout-follow-normal">
# 		<a class="bsub" href="javascript:void(0)"><span id='bsub-text'>Follow</span></a>
# 		<div id="bitsubscribe">
#
# 					<h3><label for="loggedout-follow-field">Follow &ldquo;crkyo&rdquo;</label></h3>
#
# 			<form action="https://subscribe.wordpress.com" method="post" accept-charset="utf-8" id="loggedout-follow">
# 			<p>Get every new post delivered to your Inbox.</p>
#
# 			<p id="loggedout-follow-error" style="display: none;"></p>
#
#
# 			<p><input type="email" name="email" value="Enter your email address" onfocus='this.value=(this.value=="Enter your email address") ? "" : this.value;' onblur='this.value=(this.value=="") ? "Enter your email address" : this.value;'  id="loggedout-follow-field"/></p>
#
# 			<input type="hidden" name="action" value="subscribe"/>
# 			<input type="hidden" name="blog_id" value="67957457"/>
# 			<input type="hidden" name="source" value="https://crkyo.wordpress.com/"/>
# 			<input type="hidden" name="sub-type" value="loggedout-follow"/>
#
# 			<input type="hidden" id="_wpnonce" name="_wpnonce" value="4708e617dc" /><input type="hidden" name="_wp_http_referer" value="/" />
# 			<p id='bsub-subscribe-button'><input type="submit" value="Sign me up" /></p>
# 			</form>
# 					<div id='bsub-credit'><a href="https://wordpress.com/?ref=lof">Build a website with WordPress.com</a></div>
# 		</div><!-- #bitsubscribe -->
# 	</div><!-- #bit -->
#
# 	<div id="carousel-reblog-box">
# 		<form action="" name="carousel-reblog">
# 			<textarea id="carousel-reblog-content" name="carousel-reblog-content" onclick="if ( this.value == 'Add your thoughts here... (optional)' ) { this.value = ''; }" onblur="if ( this.value == '' || this.value == '' ) { this.value = 'Add your thoughts here... (optional)'; }">Add your thoughts here... (optional)</textarea>
# 			<label for="carousel-reblog-to-blog-id" id="carousel-reblog-lblogid">Post to</label>
# 			<select name="carousel-reblog-to-blog-id" id="carousel-reblog-to-blog-id">
# 						</select>
#
# 			<div class="submit">
# 				<span class="canceltext"><a href="" class="cancel">Cancel</a></span>
# 				<input type="submit" name="carousel-reblog-submit" class="button" id="carousel-reblog-submit" value="Reblog Post" />
# 				<input type="hidden" id="carousel-reblog-blog-id" value="67957457" />
# 				<input type="hidden" id="carousel-reblog-blog-url" value="https://crkyo.wordpress.com" />
# 				<input type="hidden" id="carousel-reblog-blog-title" value="crkyo" />
# 				<input type="hidden" id="carousel-reblog-post-url" value="" />
# 				<input type="hidden" id="carousel-reblog-post-title" value="" />
# 			</div>
#
# 			<input type="hidden" id="_wpnonce" name="_wpnonce" value="15a24bb856" /><input type="hidden" name="_wp_http_referer" value="/" />		</form>
#
# 		<div class="arrow"></div>
# 	</div>
# <link rel='stylesheet' id='all-css-0' href='https://s1.wp.com/wp-content/mu-plugins/carousel/jetpack-carousel.css?m=1412618825g' type='text/css' media='all' />
# <!--[if lte IE 8]>
# <link rel='stylesheet' id='jetpack-carousel-ie8fix-css'  href='https://s1.wp.com/wp-content/mu-plugins/carousel/jetpack-carousel-ie8fix.css?m=1412618825g&#038;ver=20121024' type='text/css' media='all' />
# <![endif]-->
# <link rel='stylesheet' id='all-css-2' href='https://s2.wp.com/wp-content/mu-plugins/tiled-gallery/tiled-gallery.css?m=1401143454g' type='text/css' media='all' />
# <script type='text/javascript'>
# /* <![CDATA[ */
# var jetpackSlideshowSettings = {"spinner":"https:\/\/s1.wp.com\/wp-content\/mu-plugins\/shortcodes\/img\/slideshow-loader.gif","blog_id":"67957457","blog_subdomain":"crkyo","user_id":"0"};
# /* ]]> */
# </script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var JetpackEmojiSettings = {"base_url":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/emoji\/twemoji\/"};
# /* ]]> */
# </script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var jetpackCarouselStrings = {"widths":[370,700,1000,1200,1400,2000],"is_logged_in":"","lang":"en","ajaxurl":"https:\/\/crkyo.wordpress.com\/wp-admin\/admin-ajax.php","nonce":"6afad99e92","display_exif":"1","display_geo":"1","background_color":"black","comment":"Comment","post_comment":"Post Comment","write_comment":"Write a Comment...","loading_comments":"Loading Comments...","download_original":"View full size <span class=\"photo-size\">{0}<span class=\"photo-size-times\">\u00d7<\/span>{1}<\/span>","no_comment_text":"Please be sure to submit some text with your comment.","no_comment_email":"Please provide an email address to comment.","no_comment_author":"Please provide your name to comment.","comment_post_error":"Sorry, but there was an error posting your comment. Please try again later.","comment_approved":"Your comment was approved.","comment_unapproved":"Your comment is in moderation.","camera":"Camera","aperture":"Aperture","shutter_speed":"Shutter Speed","focal_length":"Focal Length","comment_registration":"0","require_name_email":"1","login_url":"https:\/\/crkyo.wordpress.com\/wp-login.php?redirect_to=https%3A%2F%2Fcrkyo.wordpress.com%2F2012%2F08%2F03%2Fhow-real-is-real%2F","local_comments_commenting_as":"<fieldset><label for=\"email\">Email (Required)<\/label> <input type=\"text\" name=\"email\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-email-field\" \/><\/fieldset><fieldset><label for=\"author\">Name (Required)<\/label> <input type=\"text\" name=\"author\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-author-field\" \/><\/fieldset><fieldset><label for=\"url\">Website<\/label> <input type=\"text\" name=\"url\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-url-field\" \/><\/fieldset>","reblog":"Reblog","reblogged":"Reblogged","reblog_add_thoughts":"Add your thoughts here... (optional)","reblogging":"Reblogging...","post_reblog":"Post Reblog","stats_query_args":"blog=67957457&v=wpcom&tz=0&user_id=0&subd=crkyo","is_public":"1"};
# var jetpackCarouselStrings = {"widths":[370,700,1000,1200,1400,2000],"is_logged_in":"","lang":"en","ajaxurl":"https:\/\/crkyo.wordpress.com\/wp-admin\/admin-ajax.php","nonce":"6afad99e92","display_exif":"1","display_geo":"1","background_color":"black","comment":"Comment","post_comment":"Post Comment","write_comment":"Write a Comment...","loading_comments":"Loading Comments...","download_original":"View full size <span class=\"photo-size\">{0}<span class=\"photo-size-times\">\u00d7<\/span>{1}<\/span>","no_comment_text":"Please be sure to submit some text with your comment.","no_comment_email":"Please provide an email address to comment.","no_comment_author":"Please provide your name to comment.","comment_post_error":"Sorry, but there was an error posting your comment. Please try again later.","comment_approved":"Your comment was approved.","comment_unapproved":"Your comment is in moderation.","camera":"Camera","aperture":"Aperture","shutter_speed":"Shutter Speed","focal_length":"Focal Length","comment_registration":"0","require_name_email":"1","login_url":"https:\/\/crkyo.wordpress.com\/wp-login.php?redirect_to=https%3A%2F%2Fcrkyo.wordpress.com%2F2012%2F08%2F03%2Fhow-real-is-real%2F","local_comments_commenting_as":"<fieldset><label for=\"email\">Email (Required)<\/label> <input type=\"text\" name=\"email\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-email-field\" \/><\/fieldset><fieldset><label for=\"author\">Name (Required)<\/label> <input type=\"text\" name=\"author\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-author-field\" \/><\/fieldset><fieldset><label for=\"url\">Website<\/label> <input type=\"text\" name=\"url\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-url-field\" \/><\/fieldset>","reblog":"Reblog","reblogged":"Reblogged","reblog_add_thoughts":"Add your thoughts here... (optional)","reblogging":"Reblogging...","post_reblog":"Post Reblog","stats_query_args":"blog=67957457&v=wpcom&tz=0&user_id=0&subd=crkyo","is_public":"1"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s0.wp.com/_static/??-'></script>
# <script type='text/javascript' src='https://platform.twitter.com/widgets.js?ver=20111117'></script>
# <script type='text/javascript' src='https://s0.wp.com/_static/??-eJyVy7EOQEAMANAfUnViYBDfgmsupepyivh7VpMY3/DwjDCuaqSGyw5R9sC6oZ1sRgkG6cd54OQhMqHSQYnUs4Z82jL8c+P3YyEPoRehdL31rG5pXVXUTVO70k03DU5D1g=='></script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script>	<script type="text/javascript">
# 	var skimlinks_pub_id = "725X584219"
# 	var skimlinks_sitename = "crkyo.wordpress.com";
# 	</script>
# 	<script type="text/javascript" src="https://s.skimresources.com/js/725X1342.skimlinks.js"></script><script type="text/javascript">
# ...
# <script type='text/javascript'>
# /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s2.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1380573781g'></script>
#
# 	<script>
# 		//initialize and attach hovercards to all gravatars
# 		jQuery( document ).ready( function( $ ) {
#
# 			if (typeof Gravatar === "undefined"){
# 				return;
# 			}
#
# 			if ( typeof Gravatar.init !== "function" ) {
# 				return;
# 			}
#
# 			Gravatar.profile_cb = function( hash, id ) {
# 				WPGroHo.syncProfileData( hash, id );
# 			};
# 			Gravatar.my_hash = WPGroHo.my_hash;
# 			Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 		});
# 	</script>
#
# 		<div style="display:none">
# 	</div>
#
# 	<div id="bit" class="loggedout-follow-normal">
# 		<a class="bsub" href="javascript:void(0)"><span id='bsub-text'>Follow</span></a>
# 		<div id="bitsubscribe">
#
# 					<h3><label for="loggedout-follow-field">Follow &ldquo;crkyo&rdquo;</label></h3>
#
# 			<form action="https://subscribe.wordpress.com" method="post" accept-charset="utf-8" id="loggedout-follow">
# 			<p>Get every new post delivered to your Inbox.</p>
#
# 			<p id="loggedout-follow-error" style="display: none;"></p>
#
#
# 			<p><input type="email" name="email" value="Enter your email address" onfocus='this.value=(this.value=="Enter your email address") ? "" : this.value;' onblur='this.value=(this.value=="") ? "Enter your email address" : this.value;'  id="loggedout-follow-field"/></p>
#
# 			<input type="hidden" name="action" value="subscribe"/>
# 			<input type="hidden" name="blog_id" value="67957457"/>
# 			<input type="hidden" name="source" value="https://crkyo.wordpress.com/page/29"/>
# 			<input type="hidden" name="sub-type" value="loggedout-follow"/>
#
# 			<input type="hidden" id="_wpnonce" name="_wpnonce" value="4708e617dc" /><input type="hidden" name="_wp_http_referer" value="/page/29" />
# 			<p id='bsub-subscribe-button'><input type="submit" value="Sign me up" /></p>
# 			</form>
# 					<div id='bsub-credit'><a href="https://wordpress.com/?ref=lof">Build a website with WordPress.com</a></div>
# 		</div><!-- #bitsubscribe -->
# 	</div><!-- #bit -->
# <script type='text/javascript'>
# /* <![CDATA[ */
# var JetpackEmojiSettings = {"base_url":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/emoji\/twemoji\/"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s2.wp.com/_static/??-eJyNzsEKAjEMBNAfsoaisnoQv6XW7Jp2mwbSbvfzRURQPNjTDMw7DDQxPnNBLhAUbriQR1m3QTfwMZU7JlSQeoVEzLk98at1UXYLTa5Q5i6ukcTMxNGM2Vc1I/08StXIXCdiBUw5EJT2lX99wCLOR9On3+qSznZvj8NwsLtTeACgm3YY'></script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script>	<script type="text/javascript">
# 	var skimlinks_pub_id = "725X584219"
# 	var skimlinks_sitename = "crkyo.wordpress.com";
# 	</script>
# 	<script type="text/javascript" src="https://s.skimresources.com/js/725X1342.skimlinks.js"></script><script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>
# 404
# Not Found
# Server: nginx
# Date: Mon, 19 Jan 2015 01:48:29 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Vary: Accept-Encoding
# Vary: Cookie
# X-hacker: If you're reading this, you should visit automattic.com/jobs and apply to join the fun, mention this header.
# X-Pingback: https://crkyo.wordpress.com/xmlrpc.php
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Cache-Control: no-cache, must-revalidate, max-age=60
# Pragma: no-cache
# Last-Modified: Mon, 19 Jan 2015 01:48:29 GMT
# X-nananana: Batcache
#
# <!DOCTYPE html>
# <html lang="en">
# <!--
# 	generated in 0.188 seconds
# 	12050 bytes batcached for 60 seconds
# -->
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <title>Page not found | crkyo</title>
# <link rel="profile" href="http://gmpg.org/xfn/11">
# <link rel="pingback" href="https://crkyo.wordpress.com/xmlrpc.php">
#
# <link rel="alternate" type="application/rss+xml" title="crkyo &raquo; Feed" href="https://crkyo.wordpress.com/feed/" />
# <link rel="alternate" type="application/rss+xml" title="crkyo &raquo; Comments Feed" href="https://crkyo.wordpress.com/comments/feed/" />
# <script type="text/javascript">
# /* <![CDATA[ */
# function addLoadEvent(func){var oldonload=window.onload;if(typeof window.onload!='function'){window.onload=func;}else{window.onload=function(){oldonload();func();}}}
# /* ]]> */
# </script>
# <link rel='stylesheet' id='all-css-0' href='https://s1.wp.com/_static/??-eJx9j90OgjAMRl/I2aDInfFZYNQxaNeFlRDe3mFi1KDc9eec9CvM0VgJikGBJxNpcj4kSOwJlzhKj1a/u6NN6QC/NfIDJuhRY20H8+w2eEPi3oI4h61Mau5CJDPMvnW4e8PKiHnOsdaVYGx9jYScsT2NY/Wy1rLLAbfZPniHAUefF3/KjatdzpAgTg2wDyH/knQhXLkbX4vyVJTnqjxf+gcP/4uV' type='text/css' media='all' />
# <link rel='stylesheet' id='minnow-opensans-css'  href='//fonts.googleapis.com/css?family=Open+Sans%3A300%2C400%2C700%2C700italic%2C400italic%2C300italic%7COpen+Sans+Condensed%3A700%2C700italic&#038;subset=latin%2Clatin-ext' type='text/css' media='all' />
# <link rel='stylesheet' id='all-css-2' href='https://s2.wp.com/_static/??-eJx9j8EKwjAQRH/IuNoWehK/JQlrumWzG5qE4N9bqUhF6GWYgfcOAy0Zr1JQCpQJI2ZI1UEkEW1A4iGXJ6NpyWs8+5xPsDNiNYlrIMmAUWfacsMIRAutZP6WIz+gGlZvC6n8DPNgS8uRuqBjDWsNsFK7+Sd9Hk4DBFZn+Q3c4+06dJexH4eun1++gWSm' type='text/css' media='all' />
# <link rel='stylesheet' id='print-css-2' href='https://s0.wp.com/wp-content/mu-plugins/global-print/global-print.css?m=1387483371g' type='text/css' media='print' />
# <script type='text/javascript'>
# /* <![CDATA[ */
# var LoggedOutFollow = {"invalid_email":"Your subscription did not succeed, please try again with a valid email address."};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s1.wp.com/_static/??-eJyFjd0KwjAMRl/IrttQ8EZ8lv1kJbVtapOu6NNbQUFR2FVCcr7v6BLVREEgiLasPY3oQGWGNJh6UxgWaizvdOUwTC7PwE/QXjOk22tsAsqjSYNA4zG84Q9rJBYPzFX55/utwrAilE3MgsRhuqgEjPef1tGRUdFlg4F13Q3MlEUt5BwVXXA2IDVz9qdu37aHY9e3vX0APQlvpA=='></script>
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://crkyo.wordpress.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://s1.wp.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress.com" />
# <link rel="shortcut icon" type="image/x-icon" href="https://s2.wp.com/i/favicon.ico" sizes="16x16 24x24 32x32 48x48" />
# <link rel="icon" type="image/x-icon" href="https://s2.wp.com/i/favicon.ico" sizes="16x16 24x24 32x32 48x48" />
# <link rel="apple-touch-icon-precomposed" href="https://s0.wp.com/i/webclip.png" />
# <link rel='openid.server' href='https://crkyo.wordpress.com/?openidserver=1' />
# <link rel='openid.delegate' href='https://crkyo.wordpress.com/' />
# <link rel="search" type="application/opensearchdescription+xml" href="https://crkyo.wordpress.com/osd.xml" title="crkyo" />
# <link rel="search" type="application/opensearchdescription+xml" href="http://wordpress.com/opensearch.xml" title="WordPress.com" />
# 		<style type="text/css">
# 			.recentcomments a {
# 				display: inline !important;
# 				padding: 0 !important;
# 				margin: 0 !important;
# 			}
#
# 			table.recentcommentsavatartop img.avatar, table.recentcommentsavatarend img.avatar {
# 				border: 0px;
# 				margin: 0;
# 			}
#
# 			table.recentcommentsavatartop a, table.recentcommentsavatarend a {
# 				border: 0px !important;
# 				background-color: transparent !important;
# 			}
#
# 			td.recentcommentsavatarend, td.recentcommentsavatartop {
# 				padding: 0px 0px 1px 0px;
# 				margin: 0px;
# 			}
#
# 			td.recentcommentstextend {
# 				border: none !important;
# 				padding: 0px 0px 2px 10px;
# 			}
#
# 			.rtl td.recentcommentstextend {
# 				padding: 0px 10px 2px 0px;
# 			}
#
# 			td.recentcommentstexttop {
# 				border: none;
# 				padding: 0px 0px 0px 10px;
# 			}
#
# 			.rtl td.recentcommentstexttop {
# 				padding: 0px 10px 0px 0px;
# 			}
# 		</style>
# 		<meta name="application-name" content="crkyo" /><meta name="msapplication-window" content="width=device-width;height=device-height" /><meta name="msapplication-tooltip" content="Smile! You’re at the best WordPress.com site ever" /><meta name="msapplication-task" content="name=Subscribe;action-uri=https://crkyo.wordpress.com/feed/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="msapplication-task" content="name=Sign up for a free blog;action-uri=http://wordpress.com/signup/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="msapplication-task" content="name=WordPress.com Support;action-uri=http://support.wordpress.com/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="msapplication-task" content="name=WordPress.com Forums;action-uri=http://forums.wordpress.com/;icon-uri=https://s2.wp.com/i/favicon.ico" /><meta name="title" content="crkyo on WordPress.com" />
# <meta name="description" content="Smile! You’re at the best WordPress.com site ever" />
# <style type="text/css" id="syntaxhighlighteranchor"></style>
# </head>
#
# <body class="error404 mp6 highlander-enabled highlander-light">
# <div id="page" class="hfeed site">
# 	<a class="skip-link screen-reader-text" href="#content">Skip to content</a>
#
# 	<header id="masthead" class="site-header" role="banner">
#
# 		<div class="site-branding">
# 													<h1 class="site-title"><a href="https://crkyo.wordpress.com/" rel="home">crkyo</a></h1>
# 			<h2 class="site-description">Smile! You’re at the best WordPress.com site ever</h2>
# 		</div>
#
#
# 				<div class="slide-menu">
#
#
# 		</div>
# 	</header><!-- #masthead -->
#
# 	<div id="content" class="site-content">
#
# 	<div id="primary" class="content-area">
# 		<main id="main" class="site-main" role="main">
#
# 			<section class="error-404 not-found">
# 				<header class="page-header">
# 					<h1 class="page-title">Oops! That page can&rsquo;t be found.</h1>
# 				</header><!-- .page-header -->
#
# 				<div class="page-content">
# 					<p>It looks like nothing was found at this location. Maybe try a search?</p>
#
# 					<form role="search" method="get" class="search-form" action="https://crkyo.wordpress.com/">
# 				<label>
# 					<span class="screen-reader-text">Search for:</span>
# 					<input type="search" class="search-field" placeholder="Search &hellip;" value="" name="s" title="Search for:" />
# 				</label>
# 				<input type="submit" class="search-submit" value="Search" />
# 			</form>
# 				</div><!-- .page-content -->
# 			</section><!-- .error-404 -->
#
# 		</main><!-- #main -->
# 	</div><!-- #primary -->
#
#
# 	</div><!-- #content -->
#
# 	<footer id="colophon" class="site-footer" role="contentinfo">
# 		<div class="site-info">
# 			<a href="https://wordpress.com/?ref=footer_blog">Blog at WordPress.com</a>.
# 			<span class="sep"> | </span>
# 			<a href="https://wordpress.com/themes/minnow/" title="Learn more about this theme">The Minnow Theme</a>.		</div><!-- .site-info -->
# 	</footer><!-- #colophon -->
# </div><!-- #page -->
#
# <!-- wpcom_wp_footer -->
# <script type='text/javascript' src='//0.gravatar.com/js/gprofiles.js?ver=201504x'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s2.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1380573781g'></script>
#
# 	<script>
# 		//initialize and attach hovercards to all gravatars
# 		jQuery( document ).ready( function( $ ) {
#
# 			if (typeof Gravatar === "undefined"){
# 				return;
# 			}
#
# 			if ( typeof Gravatar.init !== "function" ) {
# 				return;
# 			}
#
# 			Gravatar.profile_cb = function( hash, id ) {
# 				WPGroHo.syncProfileData( hash, id );
# 			};
# 			Gravatar.my_hash = WPGroHo.my_hash;
# 			Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 		});
# 	</script>
#
# 		<div style="display:none">
# 	</div>
#
# 	<div id="bit" class="loggedout-follow-normal">
# 		<a class="bsub" href="javascript:void(0)"><span id='bsub-text'>Follow</span></a>
# 		<div id="bitsubscribe">
#
# 					<h3><label for="loggedout-follow-field">Follow &ldquo;crkyo&rdquo;</label></h3>
#
# 			<form action="https://subscribe.wordpress.com" method="post" accept-charset="utf-8" id="loggedout-follow">
# 			<p>Get every new post delivered to your Inbox.</p>
#
# 			<p id="loggedout-follow-error" style="display: none;"></p>
#
#
# 			<p><input type="email" name="email" value="Enter your email address" onfocus='this.value=(this.value=="Enter your email address") ? "" : this.value;' onblur='this.value=(this.value=="") ? "Enter your email address" : this.value;'  id="loggedout-follow-field"/></p>
#
# 			<input type="hidden" name="action" value="subscribe"/>
# 			<input type="hidden" name="blog_id" value="67957457"/>
# 			<input type="hidden" name="source" value="https://crkyo.wordpress.com/page/30"/>
# 			<input type="hidden" name="sub-type" value="loggedout-follow"/>
#
# 			<input type="hidden" id="_wpnonce" name="_wpnonce" value="4708e617dc" /><input type="hidden" name="_wp_http_referer" value="/page/30" />
# 			<p id='bsub-subscribe-button'><input type="submit" value="Sign me up" /></p>
# 			</form>
# 					<div id='bsub-credit'><a href="https://wordpress.com/?ref=lof">Build a website with WordPress.com</a></div>
# 		</div><!-- #bitsubscribe -->
# 	</div><!-- #bit -->
# <script type='text/javascript'>
# /* <![CDATA[ */
# var JetpackEmojiSettings = {"base_url":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/emoji\/twemoji\/"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://s2.wp.com/_static/??-eJyNzsEKAjEMBNAfsoaisnoQv6XW7Jp2mwbSbvfzRURQPNjTDMw7DDQxPnNBLhAUbriQR1m3QTfwMZU7JlSQeoVEzLk98at1UXYLTa5Q5i6ukcTMxNGM2Vc1I/08StXIXCdiBUw5EJT2lX99wCLOR9On3+qSznZvj8NwsLtTeACgm3YY'></script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script>	<script type="text/javascript">
# 	var skimlinks_pub_id = "725X584219"
# 	var skimlinks_sitename = "crkyo.wordpress.com";
# 	</script>
# 	<script type="text/javascript" src="https://s.skimresources.com/js/725X1342.skimlinks.js"></script><script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>

# %%
html = str(reader())

# %%
def find_between(html, first, last ):
    try:
        start = html.index( first ) + len( first )
        end = html.index( last, start )
        return html[start:end]
    except ValueError:
        return "oops!"
    
print find_between(html, "<div class=\"entry-content\">", "<!-- .entry-content -->" )
# Out:
# oops!
